# %% [markdown]
# # [3] Numpy: 연산

# %% [markdown]
# ### [실습] 데이터를 기반으로 배열 연산 수행
#
#
# 다음과 같은 과일 판매량 데이터가 있습니다. 각 과일의 1분기와 2분기 판매량이 주어졌을 때, NumPy 배열을 사용하여 아래 문제를 해결하세요.
#
# 1. 1분기와 2분기의 과일별 총 판매량을 구하세요.
# 2. 과일별 평균 판매량을 구하세요.
#
# - **데이터**:
#     - 1분기 판매량: `[200, 340, 150, 400]` (사과, 배, 오렌지, 바나나)
#     - 2분기 판매량: `[220, 300, 180, 420]` (사과, 배, 오렌지, 바나나)

# %%
import numpy as np

# %%
fruit1 = np.array([200, 340, 150, 400])
fruit2 = np.array([220, 300, 180, 420])
# 1
total_fruit = fruit1 + fruit2
print(total_fruit)
# 2
avg_fruit = (fruit1 + fruit2) / 2
print(avg_fruit)
# Out:
# [420 640 330 820]
# [210. 320. 165. 410.]

# %% [markdown]
# ### [실습 1] 기본 산술 연산
#
#
# 다음 두 배열을 사용하여 각각의 요소별로 덧셈, 뺄셈, 곱셈, 나눗셈을 수행하세요.
#
#
# ```python
# arr1 = np.array([10, 20, 30, 40])
# arr2 = np.array([1, 2, 3, 4])
# ```

# %%
arr1 = np.array([10, 20, 30, 40])
arr2 = np.array([1, 2, 3, 4])

print(arr1 + arr2)
print(arr1 - arr2)
print(arr1 * arr2)
print(arr1 / arr2)
# Out:
# [11 22 33 44]
# [ 9 18 27 36]
# [ 10  40  90 160]
# [10. 10. 10. 10.]

# %% [markdown]
# ### [실습 2] Dot Product
#
#
# 다음 두 배열 간의 내적 연산을 수행하세요.
#
#
# ```python
# arr1 = np.array([1, 2, 3])
# arr2 = np.array([4, 5, 6])
# ```

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

print(arr1 @ arr2)
print(np.dot(arr1, arr2))
# Out:
# 32
# 32

# %% [markdown]
# ### [실습 3] 브로드캐스팅
#
#
# 아래의 2차원 배열과 1차원 배열을 브로드캐스팅하여 더하세요.
#
#
# ```python
# arr2d = np.array([[1, 2, 3], [4, 5, 6]])
# arr1d = np.array([10, 20, 30])
# ```

# %%
arr2d = np.array([[1, 2, 3], [4, 5, 6]])
arr1d = np.array([10, 20, 30])
print(arr2d + arr1d)
# Out:
# [[11 22 33]
#  [14 25 36]]

# %% [markdown]
# ### [실습 4] 비교 연산 및 집계 함수 사용
#
#
# 1. 배열에서 20보다 큰 값을 찾아 출력하세요.
# 2. 배열의 합계, 최대값, 최소값, 평균을 계산하세요.
#
# ```python
# arr = np.array([10, 20, 30, 40, 50])
# ```

# %%
arr = np.array([10, 20, 30, 40, 50])
# 1
print(arr[arr > 20])
# Out:
# [30 40 50]

# %%
# 2
print(arr.sum())
print(arr.max())
print(arr.min())
print(arr.mean())
# Out:
# 150
# 50
# 10
# 30.0
